# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

wine = pd.read_csv("Archivos/wine.csv", sep=';')
wine
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            8.4             0.170         0.31             6.7
# 1   white            6.0             0.180         0.31             1.4
# 2   white            8.6             0.360         0.26            11.1
# 3   white            6.9             0.400         0.17            12.9
# 4     red            6.8             0.785         0.00             2.4
# ..    ...            ...               ...          ...             ...
# 95  white            6.9             0.280         0.22            10.0
# 96  white            7.6             0.390         0.32             3.6
# 97  white            7.5             0.170         0.32             1.7
# 98  white            6.4             0.230         0.27             2.1
# 99  white            6.3             0.230         0.49             7.1
#
#     chlorides  free sulfur dioxide  total sulfur dioxide    pH  sulphates  \
# ...

# %%
wine.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine.columns[0]
len(wine.columns)
list_columns =  wine.columns.tolist()
list_columns.remove('pH')
list_columns.remove('type')
list_columns.remove('quality')

print(list_columns)

columny ='chlorides'

for i in range(len(list_columns)):
    column =  list_columns[i]
    plt.scatter(wine[column], wine[columny])
    plt.xlabel(column)
    plt.ylabel(columny)
    plt.show()
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'sulphates', 'alcohol']

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Configuración inicial
list_columns = wine.columns.tolist()
list_columns.remove('pH')
list_columns.remove('type')
list_columns.remove('quality')

columny = 'pH'

# Configurar el tamaño de la figura (opcional)
plt.figure(figsize=(12, 8))

# Generar los gráficos
for i, column in enumerate(list_columns):
    # Crear un DataFrame temporal con las dos columnas
    temp_df = wine[[column, columny]]
    
    # Visualización con seaborn (jointplot incluye los histogramas)
    g = sns.jointplot(data=temp_df, x=column, y=columny, kind='scatter', 
                      marginal_kws=dict(bins=25, fill=True))
    
    # Añadir línea de regresión (opcional)
    #sns.regplot(x=column, y=columny, data=wine, scatter_kws={'alpha':0.3}, line_kws={'color':'red'}, ax=g.ax_joint)
    
    # Personalización del título
    #g.fig.suptitle(f'Relación entre {column} y pH', fontsize=16)
    
    # Ajustar espacio entre la figura y el título
    g.fig.subplots_adjust(top=0.95)
    
    # Mostrar el gráfico
    plt.show()

# %%
import seaborn as sns
sns.pairplot(wine)
plt.show()
